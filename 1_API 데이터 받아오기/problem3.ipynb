# %%
# 필요 패키지 import
import pprint
import requests

# %% [markdown]
# # 문제3. 응답 중 정기예금 상품들의 옵션 리스트를 출력하도록 구성합니다.
# ##  이 때, 원하는 데이터만 추출하여 새로운 리스트를 만들어 반환하는 함수를 작성하시오.
# - [힌트] 아래와 같은 순서로 데이터를 출력하며 진행합니다.
# - 1. 응답을 json 형식으로 변환합니다.
# - 2. key 값이 "result" 인 데이터를 출력합니다.
# - 3. 위의 결과 중 key 값이 "optionList" 인 데이터를 변수에 저장합니다.
# - 4. 3번에서 저장된 값을 반복하며, 원하는 데이터만 추출 및 가공하여 결과 리스트에 저장합니다.

# %%
def get_deposit_products():
    api_key = "72624f4493711e1a4b021f735bffa37e"
    
    # 공통요구사항 사용예제
    url = 'http://finlife.fss.or.kr/finlifeapi/depositProductsSearch.json'
    params = {
        'auth' : api_key, 
        'topFinGrpNo' : '020000',
        'pageNo' : 1
    }
    # 응답을  Json으로 변환
    # response = requests.get(url, params=params).json()
    
    # # 요구사항에 맞도록 이곳의 코드를 수정합니다.
    # result = response['result']['optionList']

    option_list = requests.get(url, params=params).json()['result']['optionList']
    result = []
    for option in option_list:
        new_option = {}
        new_option['금융상품코드'] = option['fin_prdt_cd']
        new_option['저축 금리'] = option['intr_rate']
        new_option['저축 기간'] = option['save_trm']
        new_option['저축금리유형'] = option['intr_rate_type']
        new_option['저축금리유형명'] = option['intr_rate_type_nm']
        new_option['최고 우대금리'] = option['intr_rate2']
        print(new_option)
    
    # for user in result:
    #     code = user['fin_prdt_cd']
    #     rate = user['intr_rate']
    #     trm = user['save_trm']
    #     type = user['intr_rate_type']
    #     type2 = user['intr_rate_type_nm']
    #     rate2 = user['intr_rate2']
        
    #     new_dict = {}
    #     new_dict['금융상품코드'] = {code}
    #     new_dict['저축 금리'] = {rate}
    #     new_dict['저축 기간'] = {trm}
    #     new_dict['저축금리유형'] = {type}
    #     new_dict['저축금리유형명'] = {type2}
    #     new_dict['최고 우대금리'] = {rate2}
    #     print(new_dict, sep='\n')

    #     codes.append(code)
    #     rates.append(rate)
    #     trms.append(trm)
    #     types.append(type)
    #     types2.append(type)
    #     rates2.append(rate2)
    
    # new_dict = {}
    # new_dict['금융상품코드'] = {codes} 
    # new_dict['저축 금리'] = {rates}
    # new_dict['저축 기간'] = {trms}
    # new_dict['저축 기간'] = {types}
    # new_dict['저축 기간'] = {types2}
    # new_dict['저축 기간'] = {rates2}
    # print(new_dict)

# %%
# 아래 코드는 수정하지 않습니다.
if __name__ == '__main__':
    # json 형태의 데이터 반환
    result = get_deposit_products()
    # prrint.prrint(): json 을 보기 좋은 형식으로 출력
    pprint.pprint(result)
# Out:
# {'금융상품코드': 'WR0001B', '저축 금리': 3.67, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.67}
# {'금융상품코드': 'WR0001B', '저축 금리': 3.73, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.73}
# {'금융상품코드': 'WR0001B', '저축 금리': 3.36, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.36}
# {'금융상품코드': 'WR0001B', '저축 금리': 3.33, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.33}
# {'금융상품코드': '00320342', '저축 금리': 3.7, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.9}
# {'금융상품코드': '00320342', '저축 금리': 3.9, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 4.2}
# {'금융상품코드': '10511008000996000', '저축 금리': 2.46, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.11}
# {'금융상품코드': '10511008000996000', '저축 금리': 3.2, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.85}
# {'금융상품코드': '10511008000996000', '저축 금리': 3.22, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.87}
# {'금융상품코드': '10511008000996000', '저축 금리': 3.24, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.89}
# {'금융상품코드': '10511008001004000', '저축 금리': 2.42, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 2.87}
# {'금융상품코드': '10511008001004000', '저축 금리': 3.16, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.61}
# {'금융상품코드': '10511008001004000', '저축 금리': 3.18, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.63}
# {'금융상품코드': '10511008001004000', '저축 금리': 3.2, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.65}
# {'금융상품코드': '10511008001166004', '저축 금리': 3.3, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.75}
# {'금융상품코드': '10511008001278000', '저축 금리': 2.8, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.05}
# {'금융상품코드': '10511008001278000', '저축 금리': 3.5, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.75}
# {'금융상품코드': '10511008001278000', '저축 금리': 3.2, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.45}
# {'금융상품코드': '10511008001278000', '저축 금리': 3.2, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.45}
# {'금융상품코드': '10511008001516001', '저축 금리': 3.21, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.61}
# {'금융상품코드': '01030500510002', '저축 금리': 2.55, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# {'금융상품코드': '01030500510002', '저축 금리': 2.75, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.65}
# {'금융상품코드': '01030500510002', '저축 금리': 2.8, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 2.8}
# {'금융상품코드': '01030500510002', '저축 금리': 2.85, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 2.85}
# {'금융상품코드': '01030500560002', '저축 금리': 3.45, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.85}
# {'금융상품코드': '01030500560002', '저축 금리': 3.6, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 4}
# {'금융상품코드': '01030500560002', '저축 금리': 3.25, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.65}
# {'금융상품코드': '01030500560002', '저축 금리': 2.95, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.35}
# {'금융상품코드': 'TD11300027000', '저축 금리': 3.49, '저축 기간': '12', '저축금리유형': 'M', '저축금리유형명': '복리', '최고 우대금리': 3.69}
# {'금융상품코드': 'TD11300027000', '저축 금리': 3.6, '저축 기간': '24', '저축금리유형': 'M', '저축금리유형명': '복리', '최고 우대금리': 3.8}
# {'금융상품코드': 'TD11300027000', '저축 금리': 3.74, '저축 기간': '36', '저축금리유형': 'M', '저축금리유형명': '복리', '최고 우대금리': 3.94}
# {'금융상품코드': 'TD11300031000', '저축 금리': 3.35, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.45}
# {'금융상품코드': 'TD11300031000', '저축 금리': 3.39, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.59}
# {'금융상품코드': 'TD11300031000', '저축 금리': 3.5, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.7}
# {'금융상품코드': 'TD11300031000', '저축 금리': 3.64, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.84}
# {'금융상품코드': 'TD11300034000', '저축 금리': 3.2, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.7}
# {'금융상품코드': 'TD11300034000', '저축 금리': 3.3, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.8}
# {'금융상품코드': 'TD11300034000', '저축 금리': 3.1, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.1}
# {'금융상품코드': 'TD11300034000', '저축 금리': 3, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3}
# {'금융상품코드': 'TD11300035000', '저축 금리': 3.29, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.79}
# {'금융상품코드': 'TD11300036000', '저축 금리': 3.3, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.55}
# {'금융상품코드': '200000301', '저축 금리': 2.85, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 2.95}
# {'금융상품코드': '200000301', '저축 금리': 3.05, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.15}
# {'금융상품코드': '200000301', '저축 금리': 3.15, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.25}
# {'금융상품코드': '200000301', '저축 금리': 3.25, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.35}
# {'금융상품코드': '200000303', '저축 금리': 3, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# {'금융상품코드': '200000303', '저축 금리': 3.1, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.6}
# {'금융상품코드': '200000303', '저축 금리': 3, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# {'금융상품코드': '200000303', '저축 금리': 3, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# {'금융상품코드': '10-01-20-024-0046-0000', '저축 금리': 3.75, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.75}
# {'금융상품코드': '10-01-20-024-0046-0000', '저축 금리': 3.8, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.8}
# {'금융상품코드': '10-01-20-024-0059-0000', '저축 금리': 3.8, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.9}
# {'금융상품코드': '10-01-20-024-0059-0000', '저축 금리': None, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 4}
# {'금융상품코드': '10-01-20-024-0059-0000', '저축 금리': None, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 4.1}
# {'금융상품코드': '21001115', '저축 금리': 2.7, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.2}
# {'금융상품코드': '21001115', '저축 금리': 3.05, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.55}
# {'금융상품코드': '21001115', '저축 금리': 3.05, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.55}
# {'금융상품코드': '21001203', '저축 금리': 3.15, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.45}
# {'금융상품코드': '21001203', '저축 금리': 3.5, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.8}
# {'금융상품코드': '21001203', '저축 금리': 3.55, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.85}
# {'금융상품코드': '01211310121', '저축 금리': 3.45, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.65}
# {'금융상품코드': '01211310121', '저축 금리': 3.5, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.7}
# {'금융상품코드': '01211310121', '저축 금리': 3.6, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.8}
# {'금융상품코드': '01211310127', '저축 금리': 3.1, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.4}
# {'금융상품코드': '01211310127', '저축 금리': 3.25, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.55}
# {'금융상품코드': '01211310130', '저축 금리': 3.51, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.51}
# {'금융상품코드': '01211310130', '저축 금리': 3.57, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.57}
# {'금융상품코드': '01211310130', '저축 금리': 3.67, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.67}
# {'금융상품코드': '01211310130', '저축 금리': 3.75, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.75}
# {'금융상품코드': '05100', '저축 금리': 2.7, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 2.7}
# {'금융상품코드': '05100', '저축 금리': 2.7, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 2.7}
# {'금융상품코드': '05100', '저축 금리': 2.7, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 2.7}
# {'금융상품코드': '05100', '저축 금리': 2.7, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 2.7}
# {'금융상품코드': '06492', '저축 금리': 3.3, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.3}
# {'금융상품코드': '06492', '저축 금리': 3.5, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# {'금융상품코드': '06492', '저축 금리': 3.3, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.3}
# {'금융상품코드': '06492', '저축 금리': 3.3, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.3}
# {'금융상품코드': '010300100335', '저축 금리': 0.95, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.68}
# {'금융상품코드': '010300100335', '저축 금리': 0.95, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.71}
# {'금융상품코드': '010300100335', '저축 금리': 1.05, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.11}
# {'금융상품코드': '010300100335', '저축 금리': 1.15, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.12}
# {'금융상품코드': '200-0135-12', '저축 금리': 2.75, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.65}
# {'금융상품코드': '200-0135-12', '저축 금리': 2.9, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.7}
# {'금융상품코드': '200-0135-12', '저축 금리': 2.95, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.45}
# {'금융상품코드': '200-0135-12', '저축 금리': 3, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.45}
# {'금융상품코드': '10-003-1225-0001', '저축 금리': 3.4, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# {'금융상품코드': '10-003-1225-0001', '저축 금리': 3.45, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.55}
# {'금융상품코드': '10-003-1381-0001', '저축 금리': 3.1, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# {'금융상품코드': '10-003-1381-0001', '저축 금리': 3.15, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.55}
# {'금융상품코드': '10-003-1381-0001', '저축 금리': 3.4, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.8}
# {'금융상품코드': '10-003-1384-0001', '저축 금리': 3.5, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# {'금융상품코드': '10-003-1384-0001', '저축 금리': 3.55, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.85}
# {'금융상품코드': '10-003-1384-0001', '저축 금리': 3.3, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.3}
# {'금융상품코드': '10-003-1384-0001', '저축 금리': 3.4, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.4}
# {'금융상품코드': '10-003-1387-0001', '저축 금리': 3.1, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.8}
# {'금융상품코드': '4', '저축 금리': 2.3, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.65}
# {'금융상품코드': '4', '저축 금리': 2.6, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.7}
# {'금융상품코드': '4', '저축 금리': 2.7, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.25}
# {'금융상품코드': '4', '저축 금리': 2.8, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.25}
# {'금융상품코드': '01013000110000000001', '저축 금리': 3.4, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.4}
# {'금융상품코드': '01013000110000000001', '저축 금리': 3.8, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.8}
# {'금융상품코드': '01013000110000000001', '저축 금리': 3.4, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.4}
# {'금융상품코드': '01013000110000000001', '저축 금리': 3.4, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.4}
# {'금융상품코드': '10120110400011', '저축 금리': 3, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.4}
# {'금융상품코드': '10120114300011', '저축 금리': 2.95, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.3}
# {'금융상품코드': '10120114300011', '저축 금리': 3.25, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.6}
# {'금융상품코드': '10120114700011', '저축 금리': 3.8, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.8}
# {'금융상품코드': '10120114700011', '저축 금리': 4, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 4}
# {'금융상품코드': '10120116100011', '저축 금리': 2.97, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 4.02}
# {'금융상품코드': '10-01-20-388-0002', '저축 금리': 3.2, '저축 기간': '6', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.2}
# {'금융상품코드': '10-01-20-388-0002', '저축 금리': 3.5, '저축 기간': '12', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# {'금융상품코드': '10-01-20-388-0002', '저축 금리': 3.5, '저축 기간': '24', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# {'금융상품코드': '10-01-20-388-0002', '저축 금리': 3.5, '저축 기간': '36', '저축금리유형': 'S', '저축금리유형명': '단리', '최고 우대금리': 3.5}
# None
